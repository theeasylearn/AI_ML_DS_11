# %%
import pandas as pd 

s1 = pd.Series([10,20,30,40,50])
s2 = pd.Series([1,2,3,4,5])
print(s1)
print(s2)

# %%
# addition
print("addition of 2 series \n",s1.add(s2))
# Out:
# addition of 2 series
#  0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
#subtraction 
print("subtraction of 2 series\n",s1.sub(s2))
# Out:
# subtraction of 2 series
#  0     9
# 1    18
# 2    27
# 3    36
# 4    45
# dtype: int64

# %%
#multiplication
print("multiplication of 2 series\n",s1.mul(s2))
# Out:
# multiplication of 2 series
#  0     10
# 1     40
# 2     90
# 3    160
# 4    250
# dtype: int64

# %%
#division
print("Division of 2 series \n",s1.div(s2))
# Out:
# Division of 2 series
#  0    10.0
# 1    10.0
# 2    10.0
# 3    10.0
# 4    10.0
# dtype: float64

# %%
#power
print("Power of Series by 2 \n",s1.pow(3))
# Out:
# Power of Series by 2
#  0      1000
# 1      8000
# 2     27000
# 3     64000
# 4    125000
# dtype: int64

# %%
#mean
print("Mean of Series",s1.mean())
#median
print("Median of Series ",s1.median())
#sum
print("Sum of series ",s1.sum())
# Out:
# Mean of Series 30.0
# Median of Series  30.0
# Sum of series  150
