# %%
import pandas as pd

# %%
s1 = pd.read_csv('marks.csv').squeeze()
print(s1)

# %%
s2 = pd.read_csv('marks.csv',usecols=['student_name','python']).squeeze()
print(s2)

# %%
s3 = pd.read_excel('marks.xlsx',usecols=['student_name','maths','machine_learning']).squeeze()
print(s3)

# %%
df = pd.read_json('marks.json').squeeze()
s4 = df[['student_name', 'python']]
print(s4)

# %%
# before you run this code you have to run below command in terminal
# pip install tables 
s5 = pd.read_hdf('marks.h5').squeeze()
print(s5)
# Out:
#      student_name  python  maths  machine_learning
# 0    Aarav Sharma      88     92                79
# 1    Ishita Gupta      74     81                90
# 2     Rohit Verma      95     89                85
# 3    Priya Kapoor      67     72                78
# 4     Ananya Nair      81     86                92
# 5     Aarav Gupta      88     92                85
# 6    Kriti Sharma      76     84                90
# 7      Riya Singh      91     89                93
# 8     Arjun Mehta      65     78                72
# 9    Nisha Kapoor      82     88                86
# 10   Aarav Kapoor      88     92                85
# 11   Vivaan Gupta      76     81                79
# 12   Aditi Sharma      95     89                93
# 13    Sneha Reddy      62     74                70
# 14    Ishaan Nair      79     85                88
# 15   Aarav Sharma      88     92                85
# 16    Riya Kapoor      76     81                79
# ...
